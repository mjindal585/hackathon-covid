# %%
import pandas as pd

# %%
import numpy as np

# %%
xls = pd.ExcelFile('Train_dataset.xlsx')

# %%
df1 = pd.read_excel(xls,'Train_dataset')

# %%
df2 = pd.read_excel(xls , 'Diuresis_TS')

# %%
df1.to_csv('Train.csv',index=False)

# %%
df2.to_csv('Train_Diuresis_TS.csv' , index=False)

# %%
train = pd.read_csv('Train.csv')

# %%
train
# Out:
#        people_ID        Region  Gender Designation                 Name  \
# 0              1  Bhubaneshwar  Female         Mrs                mansi
# 1              2  Bhubaneshwar  Female         Mrs            riya masi
# 2              3  Bhubaneshwar  Female         Mrs               sunita
# 3              4  Bhubaneshwar  Female         Mrs       anjali @ babli
# 4              5  Bhubaneshwar  Female         Mrs      champa karketta
# ...          ...           ...     ...         ...                  ...
# 10709      22691     Bengaluru    Male          Mr               ashish
# 10710      22692     Bengaluru    Male          Mr  mohd mujahid ansari
# 10711      22693     Bengaluru    Male          Mr           munnakumar
# 10712      22694     Bengaluru    Male          Mr              prakash
# 10713      22695     Bengaluru    Male          Mr      mehboob mehandi
#
#       Married  Children     Occupation Mode_transport  cases/1M  ...    HBB  \
# ...

# %%
train_Diuresis = pd.read_csv('Train_Diuresis_TS.csv')

# %%
train_Diuresis
# Out:
#        people_ID  2020-03-20 00:00:00  2020-03-21 00:00:00  \
# 0              1                  441                544.2
# 1              2                  151                197.2
# 2              3                  416                515.2
# 3              4                  410                506.0
# 4              5                  390                483.0
# ...          ...                  ...                  ...
# 10709      22691                  134                173.8
# 10710      22692                  387                479.4
# 10711      22693                  177                228.4
# 10712      22694                  352                438.4
# 10713      22695                  181                230.2
#
#        2020-03-22 00:00:00  2020-03-23 00:00:00  2020-03-24 00:00:00  \
# 0                   669.64              821.368            1002.2416
# 1                   253.24              321.688             399.9256
# ...

# %%
train['Diuresis'] = train_Diuresis['2020-03-20 00:00:00']

# %%
train['Diuresis']
# Out:
# 0        441
# 1        151
# 2        416
# 3        410
# 4        390
#         ...
# 10709    134
# 10710    387
# 10711    177
# 10712    352
# 10713    181
# Name: Diuresis, Length: 10714, dtype: int64

# %%
train.to_csv('train_20March_Raw.csv',index=False)
